# %% [markdown]
# Make new Calculator

# %%
# Login Function demo - dswithbapy.com 

""" 
Actual Credentials:

Email: entbappy73@gmail.com 
Password: Bappy@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "entbappy73@gmail.com"
actual_password = "Bappy@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

else:
    print("Invalid Credentials!")
# Out:
# Invalid Credentials!

# %% [markdown]
# Temperature check

# %%
#input from user about Temoerature
temperature = float(input("What is the temperature in Celcious"))

#Check the temperature Range

if temperature > 30:
    print("It is hot day!")
elif temperature >= 20:
    print("It's a nice day.")
elif temperature >= 10:
    print("It's cold day")  
else:
    print("invaid infomation")
# Out:
# It is hot day!

# %%
tamim = input("what are you doing")
print(f"You are doing {tamim} ")
# i successfully ran that code,, Really amazing
# Out:
# You are doing Coding

# %%
# Ask user to enter the temperature
temperature = float(input("Enter the temperature in °C: "))

# Check the temperature range
if temperature > 30:
    print("It's a hot day!")
elif temperature >= 20:
    print("It's a nice day.")
elif temperature >= 10:
    print("It's a bit cold.")
else:
    print("It's freezing!")
# Out:
# It's a nice day.

# %% [markdown]
# Temperature Check

# %%
# Ask user , What is the Temperation
temperation = float(input("Enter the temperature in celcious: "))

#check the temperature level
if temperature > 35:
    print("It's a hot day!")

elif temperature >= 20:
    print("It's a nice day.")

elif temperature >= 10:
    print("It's a cold day!")
    
else:
    print("It's freezing!")

# %% [markdown]
# Lets Practice Again

# %%
#make temoerature cheake board
temperature = input("Enter the Temperature: ")

# cheake temperture
if temperature >= 35:
    print("Today weather is hot")
elif temperature >= 20:
    print("Today temperture is nice day")
elif temperature >= 10:
    print("Today temperature is cold")
else:
    print("Today temperture is too cold")

# %%
# student identifuer between (good/average/below avaerage)
#Input from user
previous_result = float(input("Enter your Privious restlt in GPA: "))

#lets check
if previous_result == 5.00:
  print("You are a good  very Student")
elif previous_result > 5.00:
  print("Your Input is incorrect")
elif previous_result >= 4.00:
  print("You are medium student")
elif previous_result >= 3.00:
  print("You are below average Student")
else:
  print("You are totally inconsistent student")
# Out:
# Your Input is incorrect

# %%
# today i made fuction which will prenet about your focus
screen_time = float(input("Enter your yesterday Screen on time "))
sleep = float(input("Enter your sleep last night in hours"))
physical_activity = float(input("Your daily excercise in minitue"))
read_book = input("Tell me with: Yes/NO")

#lets check
if screen_time >= 4:
    print("Your attention is finish by the phone")
elif screen_time >= 8:
    print("You will be become a poor guy")
elif sleep <= 6.5:
    print("You should improve your sleep cycle")
elif physical_activity <= 60:

    print("You are unfit now")
elif physical_activity >= 120:
    print("You are very strong guy")
elif  read_book == "yes":
    print("Congartulation. You are good learner")
elif read_book == "no":
    print("You must implement reading habits")
else:
    print("May be your input is wrong")
# Out:
# Your attention is finish by the phone
